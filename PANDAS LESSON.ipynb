# %% [markdown]
# ## Creating pandas series

# %%
import numpy as np
import pandas as pd

# %%
list1 = [1,2,3,4,5]
arr = np.array([10,20,30,40,50])
labels = ['a','b','c','d','e']
dict = {1:'priya' , 2: 'bala',3:'cricket',4: 'badminton', 5: 'gol-gappe'}

# %%
pd.Series(arr, index = labels)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# dtype: int64

# %%
pd.Series(dict)
# Out:
# 1        priya
# 2         bala
# 3      cricket
# 4    badminton
# 5    gol-gappe
# dtype: str

# %% [markdown]
# # Data Frames

# %%
# using a dictionary
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df1 = pd.DataFrame(data)
df1
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#using list
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
cols = ["name","age","city","salary"]
df2 = pd.DataFrame(data_list, columns = cols)
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df1["Salary"]
# Out:
# 0    65000
# 1    70000
# 2    62000
# 3    85000
# Name: Salary, dtype: int64

# %%
df2[["name", "age"]]
# Out:
#     name  age
# 0   John   28
# 1   Anna   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# ## creating a new column

# %%
df2["experience years"] = [1,2,3,4]
df2
# Out:
#     name  age      city  salary  experience years
# 0   John   28  New York   65000                 1
# 1   Anna   34     Paris   70000                 2
# 2  Peter   29    Berlin   62000                 3
# 3  Linda   42    London   85000                 4

# %% [markdown]
# ### removing a column

# %%
df2.drop("experience years" , axis = 1)
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     name  age      city  salary  experience years
# 0   John   28  New York   65000                 1
# 1   Anna   34     Paris   70000                 2
# 2  Peter   29    Berlin   62000                 3
# 3  Linda   42    London   85000                 4

# %%
df2.drop("experience years" , axis = 1, inplace = True)

# %%
df2
# Out:
#     name  age      city  salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# ### selecting a row

# %%
df2.loc[[0,1]]
# Out:
#    name  age      city  salary
# 0  John   28  New York   65000
# 1  Anna   34     Paris   70000

# %% [markdown]
# ### selecting a subset

# %%
df2.loc[[2,3]] [["name","age"]]
# Out:
#     name  age
# 2  Peter   29
# 3  Linda   42

# %%
df2[(df2["age"] > 30) & (df2["city"] == "Paris")]
# Out:
#    name  age   city  salary
# 1  Anna   34  Paris   70000

# %% [markdown]
# # Missing Data

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %% [markdown]
# ### remove missing data

# %%
df.dropna()
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df.dropna(thresh = 2)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna(thresh = 3)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna(thresh = 4)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %% [markdown]
# ### fill missing values

# %%
df.fillna("x")
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0    x
# 2    x  3  3.0    x
# 3  4.0  4    x    x
# 4  5.0  5    x  5.0

# %%
values = {'A':0,'B':100,"C":300,'D':400}
df.fillna(values)
# Out:
#      A  B      C      D
# 0  1.0  1    1.0    1.0
# 1  2.0  2    2.0  400.0
# 2  0.0  3    3.0  400.0
# 3  4.0  4  300.0  400.0
# 4  5.0  5  300.0    5.0

# %% [markdown]
# # Merging , Joining , Concatenation

# %% [markdown]
# ### merging

# %%
employees = pd.DataFrame({
    'employee_id': [1, 2, 3, 4, 5],
    'name': ['John', 'Anna', 'Peter', 'Linda', 'Bob'],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
})

# DataFrame 2: Salary information
salaries = pd.DataFrame({
    'employee_id': [1, 2, 3, 6, 7],
    'salary': [60000, 80000, 65000, 70000, 90000],
    'bonus': [5000, 10000, 7000, 8000, 12000]
})

# %%
employees
# Out:
#    employee_id   name department
# 0            1   John         HR
# 1            2   Anna         IT
# 2            3  Peter    Finance
# 3            4  Linda         IT
# 4            5    Bob         HR

# %%
salaries
# Out:
#    employee_id  salary  bonus
# 0            1   60000   5000
# 1            2   80000  10000
# 2            3   65000   7000
# 3            6   70000   8000
# 4            7   90000  12000

# %%
pd.merge(employees, salaries)
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
# better as no null values (AS ONLY COMMOM PART IS PRINTED.) Preffered as  null values are danger
pd.merge(employees, salaries, on = "employee_id", how = "inner")
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000

# %%
pd.merge(employees, salaries, on = "employee_id", how = "outer")
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN
# 5            6    NaN        NaN  70000.0   8000.0
# 6            7    NaN        NaN  90000.0  12000.0

# %%
pd.merge(employees, salaries, on = "employee_id", how = "left")
# Out:
#    employee_id   name department   salary    bonus
# 0            1   John         HR  60000.0   5000.0
# 1            2   Anna         IT  80000.0  10000.0
# 2            3  Peter    Finance  65000.0   7000.0
# 3            4  Linda         IT      NaN      NaN
# 4            5    Bob         HR      NaN      NaN

# %%
pd.merge(employees, salaries, on = "employee_id", how = "right")
# Out:
#    employee_id   name department  salary  bonus
# 0            1   John         HR   60000   5000
# 1            2   Anna         IT   80000  10000
# 2            3  Peter    Finance   65000   7000
# 3            6    NaN        NaN   70000   8000
# 4            7    NaN        NaN   90000  12000

# %% [markdown]
# ### concatenation

# %%
df1 = pd.DataFrame({
    'A': ['A0', 'A1', 'A2'],
    'B': ['B0', 'B1', 'B2'],
    'C': ['C0', 'C1', 'C2']
})

df2 = pd.DataFrame({
    'A': ['A3', 'A4', 'A5'],
    'B': ['B3', 'B4', 'B5'],
    'C': ['C3', 'C4', 'C5']
})

# %%
df1
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2

# %%
df2
# Out:
#     A   B   C
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat([df1,df2])
# pd.concat((df1,df2)) # axis = 0  by default
# Out:
#     A   B   C
# 0  A0  B0  C0
# 1  A1  B1  C1
# 2  A2  B2  C2
# 0  A3  B3  C3
# 1  A4  B4  C4
# 2  A5  B5  C5

# %%
pd.concat((df1,df2), axis = 1)
# Out:
#     A   B   C   A   B   C
# 0  A0  B0  C0  A3  B3  C3
# 1  A1  B1  C1  A4  B4  C4
# 2  A2  B2  C2  A5  B5  C5

# %% [markdown]
# ### joining

# %%
df1 = pd.DataFrame({
    'name': ['Alice', 'Bob', 'Charlie']
}, index=[1, 2, 3])

# Second DataFrame
df2 = pd.DataFrame({
    'score': [85, 90, 75]
}, index=[2, 3, 4])

# %%
df1
# Out:
#       name
# 1    Alice
# 2      Bob
# 3  Charlie

# %%
df2
# Out:
#    score
# 2     85
# 3     90
# 4     75

# %%
df1.join(df2)
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0

# %%
df1.join(df2 ,  how = "inner")
# Out:
#       name  score
# 2      Bob     85
# 3  Charlie     90

# %%
df1.join(df2 ,  how = "outer")
# Out:
#       name  score
# 1    Alice    NaN
# 2      Bob   85.0
# 3  Charlie   90.0
# 4      NaN   75.0

# %%
df2.join(df1 ,  how = "outer")
# Out:
#    score     name
# 1    NaN    Alice
# 2   85.0      Bob
# 3   90.0  Charlie
# 4   75.0      NaN

# %%
df2.join(df1)
# Out:
#    score     name
# 2     85      Bob
# 3     90  Charlie
# 4     75      NaN

# %% [markdown]
# # Group By Aggregation

# %%
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'],
    'Store': ['S1', 'S1', 'S2', 'S2', 'S1', 'S2', 'S2', 'S1'],
    'Sales': [100, 200, 150, 250, 120, 180, 200, 300],
    'Quantity': [10, 15, 12, 18, 8, 20, 15, 25],
    'Date': pd.date_range('2023-01-01', periods=8)
}

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 4        A    S1    120         8 2023-01-05
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07
# 7        B    S1    300        25 2023-01-08

# %%
# Group by Category and calculate the sum of Sales
category = df1.groupby("Category")
for x,y in category:
    print(x)
    print(y)
# Out:
# A
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 2        A    S2    150        12 2023-01-03
# 4        A    S1    120         8 2023-01-05
# 6        A    S2    200        15 2023-01-07
# B
#   Category Store  Sales  Quantity       Date
# 1        B    S1    200        15 2023-01-02
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 7        B    S1    300        25 2023-01-08

# %%
category = df1.groupby("Category")["Sales"].sum()
category
# Out:
# Category
# A    570
# B    930
# Name: Sales, dtype: int64

# %%
# Group by Store and calculate the sum of Sales
store = df1.groupby("Store")
for x,y in store:
    print(x)
    print(y)
# Out:
# S1
#   Category Store  Sales  Quantity       Date
# 0        A    S1    100        10 2023-01-01
# 1        B    S1    200        15 2023-01-02
# 4        A    S1    120         8 2023-01-05
# 7        B    S1    300        25 2023-01-08
# S2
#   Category Store  Sales  Quantity       Date
# 2        A    S2    150        12 2023-01-03
# 3        B    S2    250        18 2023-01-04
# 5        B    S2    180        20 2023-01-06
# 6        A    S2    200        15 2023-01-07

# %%
store = df1.groupby("Store")["Sales"].sum()
store
# Out:
# Store
# S1    720
# S2    780
# Name: Sales, dtype: int64

# %%
# Group by Category and Store together(MULTIPLE COLUMNS)
multiple = df1.groupby(["Category", "Store"])["Sales"].sum()
multiple
# Out:
# Category  Store
# A         S1       220
#           S2       350
# B         S1       500
#           S2       430
# Name: Sales, dtype: int64

# %%
df1["Sales"].mean()
# Out:
# np.float64(187.5)

# %%
df1["Sales"].agg(["mean","median","max","min","count","std"])
# .agg not applicable for mode*
# Out:
# mean      187.500000
# median    190.000000
# max       300.000000
# min       100.000000
# count       8.000000
# std        66.062741
# Name: Sales, dtype: float64

# %% [markdown]
# # Pivot Tables and Cross Tab

# %%
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West',
               'North', 'South', 'East', 'West', 'North', 'South', 'East', 'West', 'North', 'South'],
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary',
            'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice', 'John', 'Mary', 'Bob', 'Alice']
}

df = pd.DataFrame(data)

df['Month'] = df['Date'].dt.month_name()
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)
df
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    251     39   John  January      Q1
# 1  2023-01-02       B   West    711     19   Mary  January      Q1
# 2  2023-01-03       C  North    117     43    Bob  January      Q1
# 3  2023-01-04       D  South    634     26  Alice  January      Q1
# 4  2023-01-05       A   East    650     33   John  January      Q1
# 5  2023-01-06       B   West    562     60   Mary  January      Q1
# 6  2023-01-07       C  North    926     10    Bob  January      Q1
# 7  2023-01-08       D  South    124     52  Alice  January      Q1
# 8  2023-01-09       A   East    925     47   John  January      Q1
# 9  2023-01-10       B   West    420     29   Mary  January      Q1
# 10 2023-01-11       C  North    441     89    Bob  January      Q1
# 11 2023-01-12       D  South    536     14  Alice  January      Q1
# 12 2023-01-13       A   East    730     86   John  January      Q1
# 13 2023-01-14       B   West    468     62   Mary  January      Q1
# 14 2023-01-15       C  North    967     60    Bob  January      Q1
# 15 2023-01-16       D  South    997     84  Alice  January      Q1
# 16 2023-01-17       A   East    565     14   John  January      Q1
# 17 2023-01-18       B   West    411     57   Mary  January      Q1
# 18 2023-01-19       C  North    867     16    Bob  January      Q1
# 19 2023-01-20       D  South    510     10  Alice  January      Q1

# %%
pd.pivot_table(df, values = "Units", index = "Region", columns = "Product")
# Out:
# Product     A     B     C     D
# Region
# East     43.8   NaN   NaN   NaN
# North     NaN   NaN  43.6   NaN
# South     NaN   NaN   NaN  37.2
# West      NaN  45.4   NaN   NaN

# %%
pd.pivot_table(df, values = "Units", index = "Region", columns = "Product", aggfunc = "median")
# Out:
# Product     A     B     C     D
# Region
# East     39.0   NaN   NaN   NaN
# North     NaN   NaN  43.0   NaN
# South     NaN   NaN   NaN  26.0
# West      NaN  57.0   NaN   NaN

# %%
newpivot = pd.pivot_table(df, values = ["Units", "Sales"], index = "Region", columns = "Product")
newpivot
# Out:
#          Sales                      Units
# Product      A      B      C      D     A     B     C     D
# Region
# East     624.2    NaN    NaN    NaN  43.8   NaN   NaN   NaN
# North      NaN    NaN  663.6    NaN   NaN   NaN  43.6   NaN
# South      NaN    NaN    NaN  560.2   NaN   NaN   NaN  37.2
# West       NaN  514.4    NaN    NaN   NaN  45.4   NaN   NaN

# %%
pd.crosstab(df["Region"], df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %%
pd.crosstab(df["Region"], df["Product"])
# Out:
# Product  A  B  C  D
# Region
# East     5  0  0  0
# North    0  0  5  0
# South    0  0  0  5
# West     0  5  0  0

# %% [markdown]
# # Operations

# %%
df1 = pd.DataFrame({
    'A': [1, 2, 3, 4, 5],
    'B': [10, 20, 30, 40, 50],
    'C': [100, 200, 300, 400, 500]
})
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.size
# Out:
# 15

# %%
df1.columns
# Out:
# Index(['A', 'B', 'C'], dtype='str')

# %%
df1.count()
# this is a function *
# Out:
# A    5
# B    5
# C    5
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       5 non-null      int64
#  1   B       5 non-null      int64
#  2   C       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %%
df1.describe()
# Out:
#               A          B           C
# count  5.000000   5.000000    5.000000
# mean   3.000000  30.000000  300.000000
# std    1.581139  15.811388  158.113883
# min    1.000000  10.000000  100.000000
# 25%    2.000000  20.000000  200.000000
# 50%    3.000000  30.000000  300.000000
# 75%    4.000000  40.000000  400.000000
# max    5.000000  50.000000  500.000000

# %%
df1["B"] + 100
# Out:
# 0    110
# 1    120
# 2    130
# 3    140
# 4    150
# Name: B, dtype: int64

# %% [markdown]
# # DataFrames Applying Functions

# %%
df1
# Out:
#    A   B    C
# 0  1  10  100
# 1  2  20  200
# 2  3  30  300
# 3  4  40  400
# 4  5  50  500

# %%
def cube(x):
    # return x*x*x
      return x ** 3

# %%
df1["A"].apply(cube)
# Out:
# 0      1
# 1      8
# 2     27
# 3     64
# 4    125
# Name: A, dtype: int64

# %%
df1["A"].apply(lambda x : x ** 2)
# Out:
# 0     1
# 1     4
# 2     9
# 3    16
# 4    25
# Name: A, dtype: int64
